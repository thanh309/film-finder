# %%
import pandas as pd
x = pd.read_csv('/home/thanh309/film-finder/resources/data/split_film_data/film_data_part1.csv')
x
# Out:
#        fid                                  name  \
# 0   290334                                    X2
# 1  1483013                              Oblivion
# 2   421715   The Curious Case of Benjamin Button
# 3  1745960                     Top Gun: Maverick
# 4  6723592                                 Tenet
# 5    87469  Indiana Jones and the Temple of Doom
# 6    71853       Monty Python and the Holy Grail
# 7  1457767                         The Conjuring
#
#                                          description  ratingCount  \
# 0  When anti-mutant Colonel William Stryker kidna...       590239
# 1  Jack Harper, a drone repairman stationed on Ea...       563288
# 2  Benjamin Button, born in 1918 with the physica...       710804
# 3  The story involves Maverick confronting his pa...       744726
# 4  Armed with only the word "Tenet," and fighting...       614169
# 5  In 1935, Indiana Jones is tasked by Indian vil...       544719
# ...
